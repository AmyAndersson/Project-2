# %%
import pandas as pd

# %%
file_to_load = "report.csv"

# %%
#show what data we have to work with 
enviro_data = pd.read_csv(file_to_load,skiprows=1)
enviro_data.head()
# Out:
#    Taxon ID  ... Commonwealth Marine Area
# 0     66785  ...                      NaN
# 1     18340  ...                      NaN
# 2     81927  ...                      NaN
# 3     81928  ...                      NaN
# 4     81929  ...                      NaN
#
# [5 rows x 65 columns]

# %%
#drop any fields with no data
dropnan = enviro_data.dropna(axis=1, how="all")
dropnan
# Out:
#        Taxon ID  ... Commonwealth Marine Area
# 0         66785  ...                      NaN
# 1         18340  ...                      NaN
# 2         81927  ...                      NaN
# 3         81928  ...                      NaN
# 4         81929  ...                      NaN
# ...         ...  ...                      ...
# 10849        67  ...                      NaN
# 10850     25906  ...                      NaN
# 10851     25907  ...                      NaN
# 10852        68  ...                      NaN
# 10853        69  ...                      NaN
#
# [10854 rows x 65 columns]

# %%
#create a new df with only the columns that we might use for visualisations
datd_df = dropnan[["Scientific Name","Common Name","EPBC Threat Status","EPBC Threatened Species Listed Name","EPBC Threatened Species Date Effective","Kingdom","Phylum","Class","Order","Family","Genus"]]
datd_df
# Out:
#                Scientific Name  ...        Genus
# 0      Abebaioscia troglodytes  ...  Abebaioscia
# 1         Abrotanella nivigena  ...  Abrotanella
# 2        Abudefduf bengalensis  ...    Abudefduf
# 3       Abudefduf sexfasciatus  ...    Abudefduf
# 4           Abudefduf sordidus  ...    Abudefduf
# ...                        ...  ...          ...
# 10849          Zyzomys argurus  ...      Zyzomys
# 10850            Zyzomys maini  ...      Zyzomys
# 10851        Zyzomys palatalis  ...      Zyzomys
# 10852     Zyzomys pedunculatus  ...      Zyzomys
# 10853        Zyzomys woodwardi  ...      Zyzomys
#
# [10854 rows x 11 columns]

# %%
clean_data = datd_df[datd_df["EPBC Threat Status"].notnull()]
clean_data
# Out:
#              Scientific Name  \
# 10         Abutilon julianae
# 25          Acacia ammophila
# 31            Acacia anomala
# 32            Acacia aphylla
# 33             Acacia aprica
# ...                      ...
# 10834  Zosterops albogularis
# 10840     Zosterops strenuus
# 10850          Zyzomys maini
# 10851      Zyzomys palatalis
# 10852   Zyzomys pedunculatus
#
#                                              Common Name  \
# 10                               Norfolk Island Abutilon
# 25
# 31                 Grass Wattle, Chittering Grass Wattle
# 32                                  Leafless Rock Wattle
# 33                                          Blunt Wattle
# ...                                                  ...
# 10834  White-chested White-eye, Norfolk Island Silvereye
# 10840                                   Robust White-eye
# 10850    Arnhem Rock-rat, Arnhem Land Rock-rat, Kodjperr
# 10851               Carpentarian Rock-rat, Aywalirroomoo
# ...

# %%
#remove.to_csv('clean_data.csv',index=False)

# %%
#bring in all the libraries we need
from sqlalchemy import create_engine
from config import username
from config import password
from config import database
import pandas as pd

#create engine to talk to the database
engine = create_engine(f"postgresql://{username}:{password}@localhost:5432/{database}")
conn=engine.connect()

# %%
# Load panda's dataframe's to postgres sql table
remove.to_sql(name='dataone', con=engine, if_exists='append', index=True)

# %%
#show that we can then bring the database back and view all of the data
showmethemoney = pd.read_sql('select * from dataone',conn)
showmethemoney
# Out:
#             scientific_name  ...      genus
# 0         Abutilon julianae  ...   Abutilon
# 1          Acacia ammophila  ...     Acacia
# 2            Acacia anomala  ...     Acacia
# 3            Acacia aphylla  ...     Acacia
# 4             Acacia aprica  ...     Acacia
# ...                     ...  ...        ...
# 1886  Zosterops albogularis  ...  Zosterops
# 1887     Zosterops strenuus  ...  Zosterops
# 1888          Zyzomys maini  ...    Zyzomys
# 1889      Zyzomys palatalis  ...    Zyzomys
# 1890   Zyzomys pedunculatus  ...    Zyzomys
#
# [1891 rows x 11 columns]
