# %%
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
speciesfile = "data/spcs_cleaned.csv"

# Read our Kickstarter data into pandas
cleaned= pd.read_csv(speciesfile)
cleaned.count()
# Out:
# Unnamed: 0           1597
# Scientific_Name      1597
# Common_Name          1597
# Threatened_Status    1597
# ACT                  1597
# NSW                  1597
# NT                   1597
# QLD                  1597
# SA                   1597
# TAS                  1597
# VIC                  1597
# WA                   1597
# Kingdom              1597
# Class                1597
# Family               1597
# Genus                1597
# Species              1597
# dtype: int64

# %%
cleaned
# Out:
#       Unnamed: 0                     Scientific_Name  \
# 0              0                    Neophoca cinerea
# 1              1                    Mirounga leonina
# 2              2               Balaenoptera borealis
# 3              3               Balaenoptera musculus
# 4              4               Balaenoptera physalus
# ...          ...                                 ...
# 1592        1892                   Ammoniropa vigens
# 1593        1893           Carinascincus palfreymani
# 1594        1894     Thinornis cucullatus cucullatus
# 1595        1895  Petrogale lateralis kimberleyensis
# 1596        1896             Leucopatus anophthalmus
#
#                                             Common_Name  \
# 0             Australian SeaNalion, Australian Sea Lion
# 1                                Southern Elephant Seal
# 2                                             Sei Whale
# 3                                            Blue Whale
# ...

# %% [markdown]
# # ACT

# %%
cleaned_ACT = cleaned.loc[ cleaned["ACT"] == "Yes"]

# %%
cleaned_ACT
# Out:
#       Unnamed: 0                                    Scientific_Name  \
# 10            10                                   Pseudomys fumeus
# 31            31                             Pteropus poliocephalus
# 37            37                              Petrogale penicillata
# 44            44                                 Petauroides volans
# 67            67                                   Grantiella picta
# 76            76                              Hirundapus caudacutus
# 79            79                               Polytelis swainsonii
# 80            80                                  Lathamus discolor
# 92            92                                   Falco hypoleucos
# 95            95                             Botaurus poiciloptilus
# 116          116                                        Delma impar
# 118          118                              Aprasia parapulchella
# 137          137                                 Litoria raniformis
# ...

# %%
cleaned_ACT.columns
# Out:
# Index(['Unnamed: 0', 'Scientific_Name', 'Common_Name', 'Threatened_Status',
#        'Kingdom', 'Class', 'Family', 'Genus', 'Species'],
#       dtype='object')

# %%
cleaned_ACT = cleaned_ACT.drop(['ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-666bda4eec96> in <module>
# ----> 1 cleaned_ACT = cleaned_ACT.drop(['ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
cleaned_ACT= cleaned_ACT.drop(['Unnamed: 0'], axis=1)

# %%
cleaned_ACT
# Out:
#                                         Scientific_Name  \
# 10                                     Pseudomys fumeus
# 31                               Pteropus poliocephalus
# 37                                Petrogale penicillata
# 44                                   Petauroides volans
# 67                                     Grantiella picta
# 76                                Hirundapus caudacutus
# 79                                 Polytelis swainsonii
# 80                                    Lathamus discolor
# 92                                     Falco hypoleucos
# 95                               Botaurus poiciloptilus
# 116                                         Delma impar
# 118                               Aprasia parapulchella
# 137                                  Litoria raniformis
# 139                             Litoria booroolongensis
# 140                                    Litoria castanea
# 141                                       Litoria aurea
# ...

# %%
cleaned_ACT.to_csv("data/cleaned_ACT.csv")

# %% [markdown]
# # WA

# %%
cleaned_WA = cleaned.loc[ cleaned["WA"] == "Yes"]

# %%
cleaned_WA = cleaned_WA.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_WA
# Out:
#                                         Scientific_Name  \
# 0                                      Neophoca cinerea
# 2                                 Balaenoptera borealis
# 3                                 Balaenoptera musculus
# 4                                 Balaenoptera physalus
# 5                                Megaptera novaeangliae
# ...                                                 ...
# 1586                                  Hibbertia abyssus
# 1589                             Stylidium asymmetricum
# 1590                            Rhizanthella johnstonii
# 1591  Galaxias truttaceus (Western Australian popula...
# 1595                 Petrogale lateralis kimberleyensis
#
#                                     Common_Name      Threatened_Status  \
# 0     Australian SeaNalion, Australian Sea Lion             Vulnerable
# 2                                     Sei Whale             Vulnerable
# 3                                    Blue Whale             Endangered
# ...

# %%
cleaned_WA.to_csv("data/cleaned_WA.csv")

# %% [markdown]
# # TAS

# %%
cleaned_TAS = cleaned.loc[ cleaned["TAS"] == "Yes"]

# %%
cleaned_TAS = cleaned_TAS.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_TAS.count()
# Out:
# Scientific_Name      221
# Common_Name          221
# Threatened_Status    221
# Kingdom              221
# Class                221
# Family               221
# Genus                221
# Species              221
# dtype: int64

# %%
cleaned_TAS.to_csv("data/cleaned_TAS.csv")

# %% [markdown]
# # NSW

# %%
cleaned_NSW = cleaned.loc[ cleaned["NSW"] == "Yes"]

# %%
cleaned_NSW = cleaned_NSW.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_NSW.to_csv("data/cleaned_NSW.csv")

# %% [markdown]
# # QLD

# %%
cleaned_QLD = cleaned.loc[ cleaned["QLD"] == "Yes"]

# %%
cleaned_QLD= cleaned_QLD.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_QLD.to_csv("data/cleaned_QLD.csv")

# %% [markdown]
# # NT

# %%
cleaned_NT = cleaned.loc[ cleaned["NT"] == "Yes"]

# %%
cleaned_NT= cleaned_NT.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_NT.to_csv("data/cleaned_NT.csv")

# %% [markdown]
# # SA

# %%
cleaned_SA = cleaned.loc[ cleaned["SA"] == "Yes"]

# %%
cleaned_SA= cleaned_SA.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_SA.to_csv("data/cleaned_SA.csv")

# %% [markdown]
# # VIC

# %%
cleaned_VIC = cleaned.loc[ cleaned["VIC"] == "Yes"]

# %%
cleaned_VIC= cleaned_VIC.drop(['Unnamed: 0', 'ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], axis = 1)

# %%
cleaned_VIC.to_csv("data/cleaned_VIC.csv")
