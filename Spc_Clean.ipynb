# %%
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
speciesfile = "data/20200929spcs_edit.csv"

# Read our Kickstarter data into pandas
spc_DB = pd.read_csv(speciesfile)
spc_DB.count()
# Out:
# Scientific Name         1897
# Common Name             1897
# Threatened status       1897
# ACT                     1897
# NSW                     1897
# NT                      1897
# QLD                     1897
# SA                      1897
# TAS                     1897
# VIC                     1897
# WA                      1897
# ACI                     1897
# CKI                     1897
# CI                      1897
# CSI                     1897
# JBT                     1897
# NFI                     1897
# HMI                     1897
# AAT                     1897
# CMA                     1897
# Listed SPRAT TaxonID    1897
# Kingdom                 1897
# Class                   1897
# Family                  1897
# Genus                   1897
# Species                 1897
# dtype: int64

# %%
spc_DB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Scientific Name       1897 non-null   object
#  1   Common Name           1897 non-null   object
#  2   Threatened status     1897 non-null   object
#  3   ACT                   1897 non-null   object
#  4   NSW                   1897 non-null   object
#  5   NT                    1897 non-null   object
#  6   QLD                   1897 non-null   object
#  7   SA                    1897 non-null   object
#  8   TAS                   1897 non-null   object
#  9   VIC                   1897 non-null   object
#  10  WA                    1897 non-null   object
#  11  ACI                   1897 non-null   object
#  12  CKI                   1897 non-null   object
#  13  CI                    1897 non-null   object
#  14  CSI                   1897 non-null   object
# ...

# %%
spc_DB.columns
# Out:
# Index(['Scientific Name', 'Common Name', 'Threatened status', 'ACT', 'NSW',
#        'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA', 'ACI', 'CKI', 'CI', 'CSI', 'JBT',
#        'NFI', 'HMI', 'AAT', 'CMA', 'Listed SPRAT TaxonID', 'Kingdom', 'Class',
#        'Family', 'Genus', 'Species'],
#       dtype='object')

# %%
spc_DB_1 = spc_DB.loc[:, ["Scientific Name", "Common Name", "Threatened status",
                                    "ACT", "NSW", "NT", "QLD", "SA", "TAS", "VIC", "WA", 'Kingdom', 'Class',
       'Family', 'Genus', 'Species']]

# %%
spc_DB_1
# Out:
#                          Scientific Name  \
# 0                       Neophoca cinerea
# 1                       Mirounga leonina
# 2                  Balaenoptera borealis
# 3                  Balaenoptera musculus
# 4                  Balaenoptera physalus
# ...                                  ...
# 1892                   Ammoniropa vigens
# 1893           Carinascincus palfreymani
# 1894     Thinornis cucullatus cucullatus
# 1895  Petrogale lateralis kimberleyensis
# 1896             Leucopatus anophthalmus
#
#                                             Common Name  \
# 0             Australian SeaNalion, Australian Sea Lion
# 1                                Southern Elephant Seal
# 2                                             Sei Whale
# 3                                            Blue Whale
# 4                                             Fin Whale
# ...                                                 ...
# 1892                            Ammonite Pinwheel Snail
# ...

# %%
spc_DB_2 = spc_DB_1[spc_DB_1["Scientific Name"] != "Na"]
spc_DB_3 = spc_DB_2[spc_DB_1["Common Name"] != "Na"]
spc_DB_4 = spc_DB_3[spc_DB_1["Threatened status"] != "Na"]
spc_DB_5 = spc_DB_4[spc_DB_1["Kingdom"] != "Na"]
spc_DB_6 = spc_DB_5[spc_DB_1["Class"] != "Na"]
spc_DB_7 = spc_DB_6[spc_DB_1["Family"] != "Na"]
spc_DB_8 = spc_DB_7[spc_DB_1["Genus"] != "Na"]
spc_DB_9 = spc_DB_8[spc_DB_1["Species"] != "Na"]
spc_DB_9
# Out:
# C:\Users\amyel\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amyel\anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\amyel\anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\amyel\anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\amyel\anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# ...

# %%
spc_DB_9["Kingdom"].unique()
# Out:
# array(['Animalia', 'Plantae'], dtype=object)

# %%
spc_DB_9["Class"].unique()
# Out:
# array(['Mammalia', 'Aves', 'Reptilia', 'Amphibia', 'Magnoliopsida',
#        'Liliopsida', 'Polypodiatae', 'Cycadatae', 'Lycopodopiatae',
#        'Insecta', 'Actinopterygii', 'Pinatae', 'Chondrichthyes',
#        'Malacostraca', 'Oligochaeta', 'Streptophyta (no class)',
#        'Psilotatae', 'Bryopsida', 'Asteroidea', 'Gastropoda', 'Arachnida',
#        'Rhodophyceae', 'Sarcopterygii', 'Bivalvia', 'Remipedia',
#        'Onychophora (no class)'], dtype=object)

# %%
spc_DB_9["Family"].unique()
# Out:
# array(['Otariidae', 'Phocidae', 'Balaenopteridae', 'Balaenidae',
#        'Muridae', 'Megadermatidae', 'Hipposideridae', 'Vespertilionidae',
#        'Pteropodidae', 'Potoroidae', 'Vombatidae', 'Macropodidae',
#        'Petauridae', 'Burramyidae', 'Peramelidae', 'Thylacomyidae',
#        'Dasyuridae', 'Myrmecobiidae', 'Thylacinidae', 'Estrildidae',
#        'Pardalotidae', 'Meliphagidae', 'Maluridae', 'Pachycephalidae',
#        'Petroicidae', 'Atrichornithidae', 'Apodidae', 'Psittacidae',
#        'Cacatuidae', 'Scolopacidae', 'Charadriidae', 'Pedionomidae',
#        'Turnicidae', 'Falconidae', 'Megapodiidae', 'Accipitridae',
#        'Ardeidae', 'Fregatidae', 'Procellariidae', 'Diomedeidae',
#        'Hydrophiidae', 'Elapidae', 'Typhlopidae', 'Scincidae', 'Agamidae',
#        'Pygopodidae', 'Gekkonidae', 'Chelidae', 'Cheloniidae',
#        'Dermochelyidae', 'Microhylidae', 'Hylidae', 'Myobatrachidae',
#        'Limnodynastidae', 'Rubiaceae', 'Rhamnaceae', 'Euphorbiaceae',
# ...

# %%
spc_DB_9.to_csv("data/spcs_cleaned.csv")
